# %%
import pandas as pd
import re


def get_cml_metadata_convention():
    df = pd.read_csv(
        'https://raw.githubusercontent.com/OpenSenseAction/OS_data_format_conventions/main/netCDF_CML.adoc',
        #'data_PL_202302__DIST_NAME-WALBRZYSKI__NCODE-79551.csv',
        sep='|',
        skiprows=9,
    )

    df = df.drop(columns='Unnamed: 0').drop(0).set_index('Unnamed: 1')
    df.index.name = 'Dimensions'

    return df


def check_required_cml_metadata(ds):
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'

    df = get_cml_metadata_convention()
    df_required = df[(df.Requisite == ' Required') | (df.Requisite == ' Required*')]
    print('Checking required variables...')
    error_count = 0
    reqFieldsNames=[]
    for row in df_required.iterrows():
        split = re.split(r'\(|\)', row[0])
        var_name, dims = split[0].strip(), tuple(split[1].split(','))
        print(f' {var_name}')
        reqFieldsNames.append(var_name)

        try:
            ds[var_name]
            if ds[var_name].dims != dims:
                print(f"  {FAIL}dims of variable '{var_name}' are {ds[var_name].dims} but have to be {dims}{ENDC}")
                error_count += 1
            else:
                print(f"  {OKGREEN}OK{ENDC}")
        except:
            print(f"  {FAIL}Required variable '{var_name}' is missing{ENDC}")
            error_count += 1

    print()
    print(f"{FAIL}{error_count} errors found{ENDC}")
    print("=======================")
    print(reqFieldsNames)
    print("=======================")

# %%
df2 = get_cml_metadata_convention()
df2.shape
df2
# Out:
#                                                                  Type  \
# Dimensions
#  time
#  cml_id
#  sublink_id
#  *Coordinate variables (dimension)*
#  time (time)                                         int/float/double
#  cml_id (cml_id)                                               string
#  sublink_id (sublink_id)                                       string
#  *Auxiliary coordinate variables (dimension)*
#  site_0_lat (cml_id)                                     float/double
#  site_0_lon (cml_id)                                     float/double
#  site_0_elev (cml_id)                                    float/double
#  site_0_alt (cml_id)                                     float/double
#  site_1_lat (cml_id)                                     float/double
#  site_1_lon (cml_id)                                     float/double
#  site_1_elev (cml_id)                                    float/double
#  site_1_alt (cml_id)                                     float/double
#  length (cml_id)                                         float/double
#  frequency (cml_id, sublink_id)                          float/double
#  polarisation (cml_id, sublink_id)                             string
#  *Data variables (dimension)*
#  _Specifications for instantaneous sampling (SN...                NaN
#  tsl (cml_id, sublink_id, time)                          float/double
#  rsl (cml_id, sublink_id, time)                          float/double
#  _Specification for min/max sampling (NMS DAQ)**_                 NaN
#  tsl_max (cml_id, sublink_id, time)                      float/double
#  tsl_min (cml_id,sublink_id, time)                       float/double
#  tsl_avg (cml_id, sublink_id, time)                      float/double
#  rsl_max (cml_id, sublink_id, time)                      float/double
#  rsl_min (cml_id, sublink_id, time)                      float/double
#  rsl_avg (cml_id, sublink_id, time)                      float/double
# temperature_0*** (cml_id, time)                          float/double
# temperature_1*** (cml_id, time)                          float/double
# ===============                                                   NaN
# NaN                                                               NaN
# NaN                                                               NaN
# NaN                                                               NaN
#
#                                                                                            Attributes  \
# Dimensions
#  time
#  cml_id
#  sublink_id
#  *Coordinate variables (dimension)*
#  time (time)                                         units = "seconds since 1970-01-01 00:00:00 UT...
#  cml_id (cml_id)                                     long_name = “commercial_microwave_link_identi...
#  sublink_id (sublink_id)                                             long_name = “sublink_identifier”
#  *Auxiliary coordinate variables (dimension)*
#  site_0_lat (cml_id)                                 units = degrees_in_WGS84_projection, long_nam...
#  site_0_lon (cml_id)                                 units = degrees_in_WGS84_projection, long_nam...
#  site_0_elev (cml_id)                                units = metres_above_sea, long_name = “ground...
#  site_0_alt (cml_id)                                 units = metres_above_sea, long_name = “antenn...
#  site_1_lat (cml_id)                                 units = degrees_in_WGS84_projection, long_nam...
#  site_1_lon (cml_id)                                 units = degrees_in_WGS84_projection, long_nam...
#  site_1_elev (cml_id)                                units = metres_above_sea, long_name = “ground...
#  site_1_alt (cml_id)                                 units = metres_above_sea, long_name = ”antenn...
#  length (cml_id)                                     units = m, long_name = “distance_between_pair...
#  frequency (cml_id, sublink_id)                          units = MHz, long_name = “sublink_frequency”
#  polarisation (cml_id, sublink_id)                   units = no units, long_name = “sublink_polari...
#  *Data variables (dimension)*
#  _Specifications for instantaneous sampling (SN...                                                NaN
#  tsl (cml_id, sublink_id, time)                      units = dBm, coordinates = string_with_auxili...
#  rsl (cml_id, sublink_id, time)                      units = dBm, coordinates = string_with_auxili...
#  _Specification for min/max sampling (NMS DAQ)**_                                                 NaN
#  tsl_max (cml_id, sublink_id, time)                  units = dBm, coordinates = string_with_auxili...
#  tsl_min (cml_id,sublink_id, time)                   units = dBm, coordinates = string_with_auxili...
#  tsl_avg (cml_id, sublink_id, time)                  units = dBm, coordinates = string_with_auxili...
#  rsl_max (cml_id, sublink_id, time)                  units = dBm, coordinates = string_with_auxili...
#  rsl_min (cml_id, sublink_id, time)                  units = dBm, coordinates = string with metada...
#  rsl_avg (cml_id, sublink_id, time)                  units = dBm, coordinates = string_with_auxili...
# temperature_0*** (cml_id, time)                      units = degrees_of_celsius, coordinates = str...
# temperature_1*** (cml_id, time)                      units = degrees_of_celsius, coordinates = str...
# ===============                                                                                   NaN
# NaN                                                                                               NaN
# NaN                                                                                               NaN
# NaN                                                                                               NaN
#
#                                                        Requisite  \
# Dimensions
#  time
#  cml_id
#  sublink_id
#  *Coordinate variables (dimension)*
#  time (time)                                            Required
#  cml_id (cml_id)                                        Required
#  sublink_id (sublink_id)                                Required
#  *Auxiliary coordinate variables (dimension)*
#  site_0_lat (cml_id)                                    Required
#  site_0_lon (cml_id)                                    Required
#  site_0_elev (cml_id)                                   Optional
#  site_0_alt (cml_id)                                 Recommended
#  site_1_lat (cml_id)                                    Required
#  site_1_lon (cml_id)                                    Required
#  site_1_elev (cml_id)                                   Optional
#  site_1_alt (cml_id)                                 Recommended
#  length (cml_id)                                        Optional
#  frequency (cml_id, sublink_id)                         Required
#  polarisation (cml_id, sublink_id)                   Recommended
#  *Data variables (dimension)*
#  _Specifications for instantaneous sampling (SN...           NaN
#  tsl (cml_id, sublink_id, time)                        Required*
#  rsl (cml_id, sublink_id, time)                        Required*
#  _Specification for min/max sampling (NMS DAQ)**_            NaN
#  tsl_max (cml_id, sublink_id, time)                    Required*
#  tsl_min (cml_id,sublink_id, time)                     Required*
#  tsl_avg (cml_id, sublink_id, time)                     Optional
#  rsl_max (cml_id, sublink_id, time)                    Required*
#  rsl_min (cml_id, sublink_id, time)                    Required*
#  rsl_avg (cml_id, sublink_id, time)                     Optional
# temperature_0*** (cml_id, time)                         Optional
# temperature_1*** (cml_id, time)                         Optional
# ===============                                              NaN
# NaN                                                          NaN
# NaN                                                          NaN
# NaN                                                          NaN
#
#                                                                                              Comments
# Dimensions
#  time                                                Unlimited size, enforce UTC seconds since 197...
#  cml_id                                                                           Minimum length is 1
#  sublink_id                                                                       Minimum length is 1
#  *Coordinate variables (dimension)*
#  time (time)
#  cml_id (cml_id)                                           cml_id has to be unique across the network
#  sublink_id (sublink_id)                             sublink_id does not have to be unique across ...
#  *Auxiliary coordinate variables (dimension)*                                                     NaN
#  site_0_lat (cml_id)
#  site_0_lon (cml_id)
#  site_0_elev (cml_id)                                                                             NaN
#  site_0_alt (cml_id)
#  site_1_lat (cml_id)
#  site_1_lon (cml_id)
#  site_1_elev (cml_id)
#  site_1_alt (cml_id)
#  length (cml_id)
#  frequency (cml_id, sublink_id)
#  polarisation (cml_id, sublink_id)                        When string then ‘vertical’ or ‘horizontal’
#  *Data variables (dimension)*
#  _Specifications for instantaneous sampling (SN...                                                NaN
#  tsl (cml_id, sublink_id, time)
#  rsl (cml_id, sublink_id, time)
#  _Specification for min/max sampling (NMS DAQ)**_                                                 NaN
#  tsl_max (cml_id, sublink_id, time)
#  tsl_min (cml_id,sublink_id, time)
#  tsl_avg (cml_id, sublink_id, time)
#  rsl_max (cml_id, sublink_id, time)
#  rsl_min (cml_id, sublink_id, time)
#  rsl_avg (cml_id, sublink_id, time)
# temperature_0*** (cml_id, time)
# temperature_1*** (cml_id, time)
# ===============                                                                                   NaN
# NaN                                                                                               NaN
# NaN                                                                                               NaN
# NaN                                                                                               NaN

# %%
check_required_cml_metadata(df2)

# %% [markdown]
# # Second Section

# %%
def getRequiredFieldNames(ds):
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'

    df = get_cml_metadata_convention()
    df_required = df[(df.Requisite == ' Required') | (df.Requisite == ' Required*')]
    #print('Checking required variables...')
    error_count = 0
    reqFieldsNames=[]
    for row in df_required.iterrows():
        split = re.split(r'\(|\)', row[0])
        var_name, dims = split[0].strip(), tuple(split[1].split(','))
        print(f' {var_name}')
        reqFieldsNames.append(var_name)
        try:
            ds[var_name]
            if ds[var_name].dims != dims:
                #print(f"  {FAIL}dims of variable '{var_name}' are {ds[var_name].dims} but have to be {dims}{ENDC}")
                error_count += 1
            else:
                print(f"  {OKGREEN}OK{ENDC}")
        except:
            #print(f"  {FAIL}Required variable '{var_name}' is missing{ENDC}")
            error_count += 1
    return reqFieldsNames

def checkColumnNames(liste, required_fields):
    # Tüm aranan elemanların listede olup olmadığını kontrol et
    result = all(eleman in liste for eleman in required_fields)
    return result

def convertLowerCase(liste):
    # List comprehension ile tüm elemanları küçük harfe çevir
    _lowercase = [eleman.lower() for eleman in liste if isinstance(eleman, str)]
    return _lowercase


def getMissingFields(liste1, liste2):
    # Liste1'in elemanlarını kontrol et ve liste2'de bulunmayanları yeni bir listeye ekle
    missingFields = [eleman for eleman in liste1 if eleman not in liste2]
    return missingFields

# %%
fileToCheck="metadata_whole_June2021_0and1.csv"
seperatorCharacter=";"

df2 = get_cml_metadata_convention()
requiredFields=getRequiredFieldNames(df2)
requiredFieldsLower= convertLowerCase(requiredFields)
# Out:
#  time
#  cml_id
#  sublink_id
#  site_0_lat
#  site_0_lon
#  site_1_lat
#  site_1_lon
#  frequency
#  tsl
#  rsl
#  tsl_max
#  tsl_min
#  rsl_max
#  rsl_min

# %%
df = pd.read_csv(
        #'https://raw.githubusercontent.com/OpenSenseAction/OS_data_format_conventions/main/netCDF_CML.adoc',
        fileToCheck,
        sep=seperatorCharacter
    )

columnNames=df.columns.tolist()
print("Required Field Names:")
print(requiredFieldsLower)
print()
print("Original Field Names:")
print(columnNames)
print()
# convert lower case
columnNamesLower = convertLowerCase(columnNames)
print("Lower Cased Field Names:")
print(columnNamesLower)
# Out:
# Required Field Names:
# ['time', 'cml_id', 'sublink_id', 'site_0_lat', 'site_0_lon', 'site_1_lat', 'site_1_lon', 'frequency', 'tsl', 'rsl', 'tsl_max', 'tsl_min', 'rsl_max', 'rsl_min']
#
# Original Field Names:
# ['cml_id', 'isSublink', 'nRecords', 'nNAs', 'timeOfFirstAvailValue', 'timeOfLastAvailValue', 'band', 'frequency', 'polarisation', 'site_0_lon', 'site_0_lat ', 'site_1_lon', 'site_1_lat', 'length', 'id1', 'id2', 'isPairingUnique', 'nRecords.1']
#
# Lower Cased Field Names:
# ['cml_id', 'issublink', 'nrecords', 'nnas', 'timeoffirstavailvalue', 'timeoflastavailvalue', 'band', 'frequency', 'polarisation', 'site_0_lon', 'site_0_lat ', 'site_1_lon', 'site_1_lat', 'length', 'id1', 'id2', 'ispairingunique', 'nrecords.1']

# %%
check_result = checkColumnNames(columnNamesLower, requiredFieldsLower)

if check_result:
    print("All required fields are OK.")
else:
    print("Some required fields are missing!")
    missingOnes = getMissingFields(requiredFieldsLower, columnNamesLower)
    print()
    print("Missing fields:", missingOnes)
# Out:
# Some required fields are missing!
#
# Missing fields: ['time', 'sublink_id', 'site_0_lat', 'tsl', 'rsl', 'tsl_max', 'tsl_min', 'rsl_max', 'rsl_min']

# %% [markdown]
# ## Section Three

# %%
# !pip install netCDF4
# Out:
# Collecting netCDF4
#   Downloading netCDF4-1.6.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 36.8 MB/s eta 0:00:00
# Collecting cftime (from netCDF4)
#   Downloading cftime-1.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netCDF4) (2024.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from netCDF4) (1.25.2)
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.6.3 netCDF4-1.6.5

# %%
from netCDF4 import Dataset
import numpy as np

# %%
# CSV dosyasını doğru ayırıcı ile oku

csv_dosya_yolu="/content/data_PL_202302__DIST_NAME-WALBRZYSKI__NCODE-79551.csv"
df = pd.read_csv(csv_dosya_yolu, sep=';')

# Verilerin yapılandırılması
# Örnek olarak, 'START_TIME' ve 'DEVICEID'ü boyut olarak,
# 'RSL_MAX', 'RSL_MIN', 'RSL_AVG', 'TSL_MAX', 'TSL_MIN', 'TSL_AVG' değerlerini değişken olarak kullanacağız.

# Zaman boyutunu oluşturmak için benzersiz 'START_TIME' değerlerini sıralı bir şekilde alalım
start_times_unique = pd.to_datetime(df['START_TIME']).dt.strftime('%Y-%m-%d %H:%M:%S').unique()
start_times_unique.sort()  # Zamanı sırala

#
device_ids_unique = df['DEVICEID'].unique()

# create netCDF
nc_dosyasi = '/content/converted_to_nc.nc'
with Dataset(nc_dosyasi, 'w', format='NETCDF4') as nc:
    # Boyutları tanımla
    nc.createDimension('time', len(start_times_unique))
    nc.createDimension('device', len(device_ids_unique))

    # Zaman ve cihaz ID değişkenlerini oluştur
    times = nc.createVariable('time', int, ('time',))
    devices = nc.createVariable('device', str, ('device',))

    # RSL ve TSL değişkenlerini oluştur
    rsl_max = nc.createVariable('RSL_MAX', np.float32, ('time', 'device'))
    rsl_min = nc.createVariable('RSL_MIN', np.float32, ('time', 'device'))
    rsl_avg = nc.createVariable('RSL_AVG', np.float32, ('time', 'device'))
    tsl_max = nc.createVariable('TSL_MAX', np.float32, ('time', 'device'))
    tsl_min = nc.createVariable('TSL_MIN', np.float32, ('time', 'device'))
    tsl_avg = nc.createVariable('TSL_AVG', np.float32, ('time', 'device'))

    # Verileri zaman ve cihaz ID'ye göre indeksleyip değişkenlere atama yapılır
    # Bu örnek, basitlik adına, değişkenler için doğrudan değer ataması yapmamaktadır.
    # Gerçek bir uygulamada, verilerin her bir değişken için uygun şekilde ataması gerekecektir.

    # Öznitelikler ekleyelim
    nc.description = 'Data converted from CSV file'
    times.units = 'YYYY-MM-DD HH:MM:SS'
    devices.description = 'Device ID'

nc_dosyasi
# Out:
# '/content/converted_to_nc.nc'
